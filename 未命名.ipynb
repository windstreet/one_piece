# %%
import pandas as pd

pd.read_csv('~/Desktop/review/US-166446011.csv')
# Out:
#      data_result_rank        asin  \
# 0                  23  B072J438BX
# 1                  22  B0714NF64S
# 2                   7  B00004YTPV
# 3                   2  B007CWM7HI
# 4                  20  B0737CPXJT
# 5                  19  B0023NVV7I
# 6                  18  B07DLLB53M
# 7                  17  B01A7YD85W
# 8                  15  B007F9FIMY
# 9                  16  B07P5SQGS2
# 10                 13  B07P5S1T44
# 11                 14  B07PJP6B2F
# 12                 12  B07DNPHK9Q
# 13                  9  B0797Q3M1T
# 14                  3  B07RBQX6FW
# 15                385  B01BN0ZB72
# 16                390  B07MG5D9SQ
# 17                397  B07R654WKZ
# 18                389  B07DJ8F6QC
# 19                 24  B07BV71BLT
# 20                395  B07FVTLXMB
# 21                370  B07QQ1QCQZ
# 22                371  B00PZFFVUE
# 23                369  B01M6E6LAJ
# 24                368  B07HB1DW11
# 25                360  B07DLHTSWB
# ...

# %%
# !ls
# Out:
# ELK             PostgreSQL      RabbitMQ        notebook        未命名.ipynb
# Linux           README.md       east_west       tool
